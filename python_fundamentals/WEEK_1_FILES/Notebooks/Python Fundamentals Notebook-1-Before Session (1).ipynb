# %% [markdown]
# ## Python Fundamentals Notebook - 1

# %% [markdown]
# **Introduction to Python Programming**
#
# **🔹 What is Python?**
#
# Python is a high-level, easy-to-read programming language used to tell the computer what to do — step by step.
# It focuses on simplicity and readability, which makes it perfect for beginners and non-IT learners.
#
# **🔹 Where Did Python Come From?**
#
# Created by: Guido van Rossum
#
# Year: 1991
#
# Named After: “Monty Python’s Flying Circus”, a British comedy show — not the snake!
#
# Python was designed to make coding fun, simple, and beginner-friendly.
#
# **🔹 Why is Python So Popular Today?**
#
# Python is used everywhere — from websites to robots — and is one of the most loved languages for Data Science and AI because:
#
# It is completely free and open-source
# (You can download, use, and share it without paying anything!)
#
# It has powerful libraries like NumPy, Pandas, and Scikit-learn.
#
# It’s easy to learn even for non-programmers.
#
# It has a large, supportive global community.

# %% [markdown]
# ## Table of Content
#
# 1. **[Python Variables](#variables)**
# 2. **[Data Types](#type)**
#     - 2.1 - [Numbers](#num)
#     - 2.2 - [Strings](#str)
#     - 2.3 - [Boolean](#bool)
# 3. **[Type Conversion](#typecon)**
# 4. **[Python print()](#print)**
# 5. **[User Input](#uinput)**
# 6. **[Python Operators](#oper)**
#     - 6.1 - [Arithmetic Operator](#arith)
#     - 6.2 - [Comparison Operator](#comp)
#     - 6.3 - [Assignment Operator](#assign)
#     - 6.4 - [Logical Operator](#logic)
#     - 6.5 - [Membership Operator](#member)

# %% [markdown]
# <a id="variables"> </a>
# ## Python Variables
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="https://github.com/markondavineeth25/nareshIT/blob/main/python_fundamentals/WEEK_1_FILES/Notebooks/note.png?raw=1">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Variables are nothing but reserved memory locations to store values. This implies that when you create a variable, you hold some space in the memory.
#
# Based on the data type of a variable, the interpreter allocates memory and decides what can be stored in the reserved memory. Therefore, by assigning different data types to variables, you can store integers, decimals or characters in these variables.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# #### Declaring and assigning a value to a variable
# We use the assignment operator  '='  to assign a value to a variable.

# %%
# Cell : write the code in the cell
# After writing the code we need to execute the code
# to execute the code we need compiler help, how to execute: select the cell in which code is written and click on run or shift+enter or cntrl+enter

# %% [markdown]
# #### Multiple assignments
# Python allows you to assign a single value to several variables simultaneously. For example −

# %%
# once the variable is used for a different value the existing value will be removed by GARBAGE COLLECTOR

# %%
# when we declare the same variable to a new value the old value will be override.

# %% [markdown]
# You can also assign multiple objects to multiple variables

# %% [markdown]
# #### Re-assigning a variable

# %% [markdown]
# ### Rules and Naming Conventions:
#
# 1. Constant and variable names should have a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore(_).
# For example:  variable_name, VARIABLE_NAME, varName, Variable_1, Variable_2.
# 2. Create a name that makes sense.
# 3. If you want to create a variable name having two words, use underscore to separate them.
# 4. Never use special symbols like !, @, #, $, %, etc.
# 5. Do not start a variable name with a digit
# 6. Reserved words (built-in keywords) cannot be used as variable names.

# %% [markdown]
#
# <a id="list"> </a>
# ## Data Types
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="https://github.com/markondavineeth25/nareshIT/blob/main/python_fundamentals/WEEK_1_FILES/Notebooks/note.png?raw=1">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>A data type is an attribute of data which tells the compiler or interpreter how the programmer intends to use the data. Python supports the following Python data types:<br><br>
#                         1. Numbers<br>
#                         2. Strings<br>
#                         3. Boolean<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Numbers
# Python numeric Python data type:<br>
# a. int (signed integers)<br>
# b. float (floating point real values)<br>
#
# <table>
#   <tr>
#   <th>int</th>
#   <th>float</th>
#   </tr>
#   <tr>
#   <td>10</td>
#   <td>54.4</td>
#   </tr>
# </table>

# %% [markdown]
# #### int
# 'int' stands for integer. This Python Data Type holds signed integers. We can use the type() function to find which class it belongs to.

# %% [markdown]
# #### float
# float stands for floating-point number. This Python data type holds decimal (fractional) numbers, We can use the type() function to find which class it belongs to.

# %% [markdown]
# <a id="str"> </a>
# #### Strings

# %% [markdown]
# A string is a sequence of characters.  You can delimit a string using single quotes('string') or double-quotes("string").

# %% [markdown]
# The plus (+) sign is the string concatenation operator and the asterisk (*) is the repetition operator.

# %% [markdown]
# #### You cannot use the minus(-) operator and the division(/) operator on strings.

# %% [markdown]
# #### boolean
# boolean (or bool) is a Python data type that represents logical values. It can hold only two possible values: True or False. Booleans are commonly used for decision-making and comparisons in programs. We can use the type() function to find which class it belongs to.

# %% [markdown]
# #### Indexing

# %% [markdown]
# Subsets of strings can be taken using the slice operator ([ ]). You can display a character from a string using its index in the string. Remember, indexing starts with 0.

# %% [markdown]
# <a id="list"> </a>
# ## Type Conversion
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="https://github.com/markondavineeth25/nareshIT/blob/main/python_fundamentals/WEEK_1_FILES/Notebooks/note.png?raw=1">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Since Python is dynamically-typed, you may want to convert a value into another type. Python supports different type conversion functions like int(), float(), str() etc.<br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# float can be converted to int
# boolean can be converted to int
# we cannot convert a string to int but if the string consists of only number we can convert to int

# %% [markdown]
# #### float()
# It converts the passed value into a float.

# %% [markdown]
# ## String conversions

# %%
num = 10
type(num)
num_updated = str(num)
type(num_updated)
# Out:
# str

# %%
weight = 80.6
type(weight)
updated_weight = str(weight)
type(updated_weight)
# Out:
# str

# %%
bool_data = True
type(bool_data)
updated_data = str(bool_data)
type(updated_data)
# Out:
# str

# %%
bool_data = False
type(bool_data)
updated_bool = str(bool_data)
type(updated_bool)
# Out:
# str

# %%
# @title AI prompt cell

import ipywidgets as widgets
from IPython.display import display, HTML, Markdown,clear_output
from google.colab import ai

dropdown = widgets.Dropdown(
    options=[],
    layout={'width': 'auto'}
)

def update_model_list(new_options):
    dropdown.options = new_options
update_model_list(ai.list_models())

text_input = widgets.Textarea(
    placeholder='Ask me anything....',
    layout={'width': 'auto', 'height': '100px'},
)

button = widgets.Button(
    description='Submit Text',
    disabled=False,
    tooltip='Click to submit the text',
    icon='check'
)

output_area = widgets.Output(
     layout={'width': 'auto', 'max_height': '300px','overflow_y': 'scroll'}
)

def on_button_clicked(b):
    with output_area:
        output_area.clear_output(wait=False)
        accumulated_content = ""
        for new_chunk in ai.generate_text(prompt=text_input.value, model_name=dropdown.value, stream=True):
            if new_chunk is None:
                continue
            accumulated_content += new_chunk
            clear_output(wait=True)
            display(Markdown(accumulated_content))

button.on_click(on_button_clicked)
vbox = widgets.GridBox([dropdown, text_input, button, output_area])

display(HTML("""
<style>
.widget-dropdown select {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
.widget-textarea textarea {
    font-size: 18px;
    font-family: "Arial", sans-serif;
}
</style>
"""))
display(vbox)
# Out:
# <style>
# .widget-dropdown select {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# .widget-textarea textarea {
#     font-size: 18px;
#     font-family: "Arial", sans-serif;
# }
# </style>
# GridBox(children=(Dropdown(layout=Layout(width='auto'), options=('google/gemini-2.5-flash', 'google/gemini-2.5…

# %% [markdown]
# You cannot turn a string into an float. It throws an error. However, if the string has only numbers, then you can.

# %% [markdown]
# #### int()
# Conversion from float to int will round-off the value (make it closer to zero).

# %% [markdown]
#  You can also turn a Boolean into an int.

# %% [markdown]
# You cannot turn a string into an int. It throws an error. However, if the string has only numbers, then you can.

# %% [markdown]
# #### str()
# <em>str()</em> converts the value into a string.

# %% [markdown]
# <a id="print"> </a>
# ## Python print()

# %% [markdown]
# print(objects, sep=' ', end='\n', )
#
# print() Parameters:
#
# objects - object to be printed. * indicates that there may be more than one object
#
# sep - objects are separated by sep. Default value: ' '
#
# end - end is printed at last

# %% [markdown]
# #### print() with separator and end parameters
# By default, python's print() function ends with a newline. This function comes with a parameter called 'end.' The default value of this parameter is '\n,' i.e., the new line character. You can end a print statement with any character or string using this parameter.<br>
# Sometimes you need to print one blank line in your Python program.

# %% [markdown]
# ## User Input
#
#
# Most programs today use a dialog box as a way of asking the user to provide some type of input.
#
# In Python input() function is used to read data from the user.
#
# You can store the results from them into a variable.

# %% [markdown]
# The Python input() function is used to read data from a standard input such as a keyboard and treats the received data as string. Basically, when we enter digit value, input() in python 3 stores it as string value. So to convert string value to integer value, we will use int() function just as shown below.

# %% [markdown]
# When <em>input()</em> function executes program flow will be stopped until the user has given an input. The message displayed on the output screen to ask a user to enter input value is optional i.e. the prompt, will be printed on the screen is optional.
# Whatever you enter as input, input function convert it into a string. If you enter an integer value still input() function convert it into a string. You need to explicitly convert it into an integer in your code using typecasting.

# %% [markdown]
# <a id="list"> </a>
# ## Python Operators
# <table align="left">
#     <tr>
#         <td width="15%">
#             <img src="https://github.com/markondavineeth25/nareshIT/blob/main/python_fundamentals/WEEK_1_FILES/Notebooks/note.png?raw=1">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>Operators are special symbols in Python that carry out arithmetic or logical computation. The value that the operator operates on is called the operand.<br>
#                         <br>Python Operator falls into following categories:
#                         <br>1. Arithmetic Operator
#                         <br>2. Comparison Operator
#                         <br>3. Assignment Operator
#                         <br>4. Logical Operator
#                         <br>5. Membership Operator
# <br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <a id="arith"> </a>
# ### Arithmetic Operator
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication etc.

# %% [markdown]
# <a id="comp"> </a>
# ### Comparison Operator
# Comparison Operator carries out the comparison between operands. They tell us whether an operand is greater than the other, lesser, equal, or a combination of those. It either returns <em>True</em> or <em>False</em> according to the condition.

# %% [markdown]
# <a id="assign"> </a>
# ### Assignment Operator
# An assignment operator assigns a value to a variable. It may manipulate the value by a factor before assigning it.

# %% [markdown]
# <a id="logic"> </a>
# ### Logical Operators
# Logical operators are like conjunctions that you can use to combine more than one condition. We have three Python logical operator – **<em>and</em>**, **<em>or</em>**, and **<em>not</em>** that come under python operators.

# %% [markdown]
# #### 'and' Operator
# If the conditions on both the sides of the operator are true, then the expression as a whole is true.

# %% [markdown]
# #### 'or' Operator
# The expression is false only if both the statements around the operator are false. Otherwise, it is true.

# %% [markdown]
# #### 'not' Operator
# It converts True to False, and False to True. So, basically, <em>not</em> inverts the Boolean value of an expression

# %% [markdown]
# <a id="member"> </a>
# ### Membership Operator

# %% [markdown]
# Membership operators tests whether a value is a member of a sequence. The sequence may be a list, a string, a tuple, or a dictionary. <br>
# <br><em>in</em> and <em>not in</em> are the membership operators in Python. The output is in terms of True or False.
