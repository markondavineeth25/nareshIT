# %% [markdown]
# ## Python Week-1 Practise File

# %% [markdown]
# **Python Variables**

# %% [markdown]
# ##### 1. Create a variable city and assign the name of your hometown to it. Print the value.

# %% [markdown]
# ##### 2. Store your age in a variable called age and print “I am X years old,” replacing X with your age.

# %% [markdown]
# ##### 3. Assign the same value (e.g., 100) to three variables a, b, and c in one line, then print them.

# %% [markdown]
# **Data Types**<br>
# Strings<br>
# Numerical<br>
# Boolean<br>

# %% [markdown]
# ##### 4.1.Declare a string variable and check its data type.

# %% [markdown]
# ##### 4.2.Declare a numeric variable and check its data type.
# i. Declare an interger variable.
# ii. Declare a float variable.

# %% [markdown]
# ##### 4.3.Declare a boolean variable and check its data type.

# %% [markdown]
# ##### 4.4.Given the string 'Today is a sunny day.'
# i.Write a code to get 'Today'
# iiWrite a code to get 'sunny'.<br>
# iii. Obtain the last two letters.<br>
# iv.Write the statement backwards.<br>

# %% [markdown]
# ##### 4.5.Create a string with the variable name 'country' and 'India' as its element. Perform the following on it:
# i.Extract this 'Ida'.<br>
# ii.Extract first two letters.<br>
# iii.Extract this 'adI'

# %% [markdown]
# **Type Conversion**

# %% [markdown]
# ##### 5. Convert a float variable f = 23.45 to integer.

# %% [markdown]
# ##### 6. Create a numberic variable and convert it to a string.

# %% [markdown]
# **Operators**

# %% [markdown]
# ##### 7. Evaluate  and print the results of the following
# 1. 1353 plus 234
# 2. 2355 minus 346
# 3. 234 times 457
# 4. 25 divided by 6
# 5. Obtain remainder of  25 divided by 6
# 6. 33 raised to 4
# 7. 45 divided by 6
# 8. 2 raised to 10

# %% [markdown]
# ##### 8. Concatenate the variables string_1 ='How are you?' and string_2 = 'Iam Fine' using '+' operator.

# %% [markdown]
# ##### 9.A bookstore sells notebooks for ₹50 each and pens for ₹20 each.Write a Python program to calculate the total bill

# %% [markdown]
# **Boolean Operations**

# %% [markdown]
# ##### 10.Check whether the expression (54+34)* 45 is equal to the expression (0.9*2432)/0.9

# %% [markdown]
# **User Input**

# %% [markdown]
# ##### 11.Calculate BMI of a person (take input for height and weight from user).
# BMI = Weight(KG)/Height(m**2)

# %% [markdown]
# ##### 12.Calculate Area of a Rectangle (take input for length and width from user).

# %% [markdown]
# **Print()**

# %% [markdown]
# ##### 13. Print this statement "Hello, How are you?"

# %% [markdown]
# ##### 14. Display the following pattern using print()

# %% [markdown]
#             *
#            ***
#           *****
#          *******
#         *********
