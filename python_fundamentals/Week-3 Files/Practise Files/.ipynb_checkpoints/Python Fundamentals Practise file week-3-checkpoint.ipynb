# %% [markdown]
# ### Python Fundamentals Practise Week-3

# %% [markdown]
# ### Conditioanl Statements

# %% [markdown]
# #### 1.Write a program to check whether number 28 is multiple of 7 (use if statement)

# %% [markdown]
# #### 2. Write a code to print the maximum of two numbers (use if-else)(Take input of 2 numbers from user)<br>

# %% [markdown]
# #### 3. Write a program to check whether a number is positive, negative or zero (use if-elif)
#
# x = -6

# %% [markdown]
# #### 4. Write a progeam to check whether a person is qualified in an exam based on marks. (Marks > 60 Qualified, < 60 not qualified). (Take input from user)

# %% [markdown]
# #### 5. Write a program to check whether number 21 is divisible by both 3 & 7

# %% [markdown]
# #### 6.Write a Python program using nested if statements to determine whether a person is eligible for a loan approval.
#
# The eligibility criteria are:<br>
# 1.The person must be employed ("yes" /"no") and<br>
# 2.The monthly salary must be greater than ₹30,000 and <br>
# 3.The credit score must be above 700.<br>
#
# If all conditions are met, print: He is eligible for loan if not print the reason why he is not eligible for loan(not employed/low salary/low credit score). Take all the inputs from user

# %% [markdown]
# ### Loops

# %% [markdown]
# #### 7.Write a for loop to print all odd Numbers from 1 to 20

# %% [markdown]
# #### 8.Write a Python program that creates an empty list and uses a for loop to append all odd numbers between 1 and 20 to the list. Finally, print the list.

# %% [markdown]
# #### 9.Write a Python program that created and empty list and uses for loop to append all vowels from word "Data Science" to the list. Finally, print the list.(Consider repeated characters)

# %% [markdown]
# #### 10.Write a Python program that counts how many numbers in a list are greater than 50 using for loop.
# numbers = [10, 60, 45, 70, 90, 30]

# %% [markdown]
# #### 11.Write a Python program that asks the user to enter a word and then counts how many vowels (a, e, i, o, u) are in it using a for loop

# %% [markdown]
# #### 12.Write a Python program that uses a while loop to calculate the sum of numbers from 1 to 10.

# %% [markdown]
# ### Functions

# %% [markdown]
# ####  13.Define the python function which adds two global numeric variables (1204 and 344536)

# %% [markdown]
# #### 14.Define a function find the sum of all numbers in a given list

# %% [markdown]
# #### 15.Define a function that checks whether a number entered by the user is a palindrome or not. (A palindrome number reads the same forward and backward — e.g., 121, 1331, 4554.)

# %% [markdown]
# #### 16.Define the python function to swap first and last value of the given list

# %% [markdown]
# #### 17.Define a python function to calculate the factorial of the number

# %% [markdown]
# #### 18.Define a python function to check whether given year is leap year or not.

# %% [markdown]
# #### 19.Write a Python program using list comprehension to create a list of squares of numbers from 1 to 10.

# %% [markdown]
# #### 20.Write a Python program using map() to convert all strings in a list to uppercase using map() function

# %% [markdown]
# #### 21.Write a Python program using filter() to get all even numbers from a list.

# %% [markdown]
# #### 22.Write a Python program using reduce() to find the product of all numbers in a list
#
# num = [2,3,4,5,6]
