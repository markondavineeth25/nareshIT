# %% [markdown]
# ### Python Fundamentals Week-2 Practise File

# %% [markdown]
# ### List

# %% [markdown]
# ### 1. Write a program to perform following list operations on the list given below:
# mix_list_1 = ['Learn', 24, 'Blue', False, -8]
#
# mix_list_2 = [4, 7, 'Summer']

# %% [markdown]
# ##### a. Check the length of mix_list_1<br>

# %% [markdown]
# ##### b. Check the membership of '24' in mix_list_1. (check if the element '24' is present in the list or not)

# %% [markdown]
# ##### c. Concatenate the mix_list_1 and mix_list_2

# %% [markdown]
# ##### d. Repeat the mix_list_2 three times

# %% [markdown]
# ### 2. Write the program to multiply the two lists
# ##### Lists to perform multiplication:
#
# num_list_1 = [1, 2, 3, 4]
#
# num_list_2 = [0, 5, 2, 1]

# %% [markdown]
# ### 3. Write a code to retrieve elements from a list<br>
#
# **Use the below list**
#
# mix_list = ['Python', 1, 2, 3, 'Data', True]

# %% [markdown]
# ##### a. First element

# %% [markdown]
# ##### b. Second last element

# %% [markdown]
# ##### c. First three elements

# %% [markdown]
# ##### d. Slice the list from 1st index till the last index with an increment of an index by 2

# %% [markdown]
# ### 4.Write a program to perform following built-in list operations:
#
# **Use the below list**
#
# num_list = [4, 5, 7, -2, 0, 1]

# %% [markdown]
# ##### a. Min(list)

# %% [markdown]
# ##### b. Max(list)

# %% [markdown]
# ##### c. Sort the elements (use sort() and sorted() function)

# %% [markdown]
# ##### d. Create a copy of a list

# %% [markdown]
# ##### e. Remove element '5' from the list

# %% [markdown]
# ### 5. Manipulating a list:
#
# ##### Use the below list
#
# languages_list = ['R', 'Python', 'C', 'Java']

# %% [markdown]
# ##### a. Add a new element 'Data' in the given list<br>

# %% [markdown]
# ##### b. Add elements 'Excel' and 'Data' in the given list

# %% [markdown]
# ###  Tuple

# %% [markdown]
# ### 6. Write a code to perform operations on tuple:
#
# **Tuples to perform operations:**
#
# num_tuple = (4, 4, 8)
#
# mix_tuple = 'John', 5, -2

# %% [markdown]
# ##### a. Check the length of num_tuple

# %% [markdown]
# ##### b. Concatenate the num_tuple and mix_tuple

# %% [markdown]
# ##### c. Repeat the mix_tuple two times

# %% [markdown]
# ### 7.Add a new element '4' to the given tuple
#
# **Use the tuple below:**
#
# mix_tuple = (['a', 1, True], 2, 'Science', -5)

# %% [markdown]
# ### Dictionary

# %% [markdown]
# ### 8. Write a code to add a key to a dictionary
#
# **Use the given dictionary and add a key (4:16)**
#
# square_dictionary = {1:1, 2:4, 3:9}

# %% [markdown]
# ### 9.Write a program to retrieve the keys/values of dictionary
#
# **Use the dictionary**
#
# mix_dictionary = {0:3, 'x':5, 1:2}

# %% [markdown]
# ### 10. Write a program to get the value for 'Age' from the dictionary

# %% [markdown]
# ### Set

# %% [markdown]
# ### 1. Write the program to perform following manipulations:
#
# **Use the below set for manipulation**
#
# num_set = {1, 2, 3, 4, 5, 6}

# %% [markdown]
# ##### a. Add '7' to the given set

# %% [markdown]
# ##### b. Remove '3' from a given set

# %% [markdown]
# ##### c. Clear the set

# %% [markdown]
# ### 12. Create two sets of words from the given sentences and perform the following operations:

# %% [markdown]
# **Use the sets given below:**
#
# set_1 = {'We', 'analyse', 'data', 'python', 'shall', 'the', 'using'}<br>
# set_2 = {'Python', 'data', 'for', 'science'}

# %% [markdown]
# ##### a. Find the common words in both the sentences

# %% [markdown]
# ##### b. Find the unique words in both the sentences
